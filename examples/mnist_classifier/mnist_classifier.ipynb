# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import seaborn as sns
sns.set_context("paper")
sns.set_style("ticks")

# %% [markdown]
# # Training a neural network
#
# This tutorial will show how to set up neural network training in a stateful way.
# Why stateful? Because we want to be able to pause training, save the model, and resume training later.
# This is especially valuable when training expensive models on large datasets, where you don't want to lose training progress if something goes wrong.
#
# ## Generating the training objects
#
# We will use a factory pattern to generate the training objects (e.g. model, optimizer, loss function, dataloader, etc).

# %%
from ml_templates.state_evolution.train_with_checkpoints import (
    state_factory, 
    read_yaml,
    run_training
)

# %% [markdown]
# The callable `state_factory` is the factory that generates stuff.
# You tell it the type of object you want (as a `str`) as well as any hyperparameters.
# It will then return an instance of that object.
#
# Note that factories can have subfactories. That is actually what we have done here. Check out the `state_factory` module to see the implementation details.
#
# Let's create a train state object:

# %%
# These hyperparameters uniquely specify a state.
state_hyperparams = dict(
    model_name             = "cnn",
    model_hyperparams      = dict(seed=0),
    dataloader_name        = "mnist",
    dataloader_hyperparams = dict(raw_data_dir="MNIST", batch_size=32),
    loss_name              = "mse",
    loss_hyperparams       = dict(),
    optimizer_name         = "adam",
    optimizer_hyperparams  = dict(learning_rate=1e-3)
)

# Use the factory to generate a state object.
state = state_factory.generate("state", state_hyperparams)
state
# Out:
# State(
#   model=CNN(
#     layers=[
#       Conv2d(
#         num_spatial_dims=2,
#         weight=f32[32,1,3,3],
#         bias=f32[32,1,1],
#         in_channels=1,
#         out_channels=32,
#         kernel_size=(3, 3),
#         stride=(1, 1),
#         padding=((0, 0), (0, 0)),
#         dilation=(1, 1),
#         groups=1,
#         use_bias=True,
#         padding_mode='ZEROS'
#       ),
#       <wrapped function relu>,
#       MaxPool2d(
#         init=-inf,
#         operation=<function max>,
#         num_spatial_dims=2,
#         kernel_size=(2, 2),
#         stride=(1, 1),
#         padding=((0, 0), (0, 0)),
#         use_ceil=False
#       ),
#       Conv2d(
#         num_spatial_dims=2,
#         weight=f32[64,32,3,3],
#         bias=f32[64,1,1],
#         in_channels=32,
#         out_channels=64,
#         kernel_size=(3, 3),
#         stride=(1, 1),
#         padding=((0, 0), (0, 0)),
#         dilation=(1, 1),
#         groups=1,
#         use_bias=True,
#         padding_mode='ZEROS'
#       ),
#       <wrapped function relu>,
#       MaxPool2d(
#         init=-inf,
#         operation=<function max>,
#         num_spatial_dims=2,
#         kernel_size=(2, 2),
#         stride=(1, 1),
#         padding=((0, 0), (0, 0)),
#         use_ceil=False
#       ),
#       <wrapped function ravel>,
#       Linear(
#         weight=f32[128,30976],
#         bias=f32[128],
#         in_features=30976,
#         out_features=128,
#         use_bias=True
#       ),
#       <wrapped function relu>,
#       Linear(
#         weight=f32[10,128],
#         bias=f32[10],
#         in_features=128,
#         out_features=10,
#         use_bias=True
#       ),
#       <wrapped function log_softmax>
#     ]
#   ),
#   dataloader=MNISTDataLoader(
#     train_state_dict={
#       '_index_sampler_state':
#       {
#         'samples_yielded':
#         0,
#         'sampler_iter_state':
#         {'generator': u8[5056](torch), 'yielded': 0}
#       },
#       '_sampler_iter_state':
#       None,
#       '_sampler_iter_yielded':
#       0,
#       '_num_yielded':
#       0,
#       '_IterableDataset_len_called':
#       None,
#       '_shared_seed':
#       None,
#       'fetcher_state':
#       None,
#       'dataset_state':
#       None,
#       '_iterator_finished':
#       False
#     },
#     train_iterable=<torchdata.stateful_dataloader.stateful_dataloader.StatefulDataLoader object at 0x314ee8ad0>,
#     i_batch=0,
#     i_epoch=0,
#     test_iterable=<torchdata.stateful_dataloader.stateful_dataloader.StatefulDataLoader object at 0x314f0a690>,
#     raw_data_dir='MNIST'
#   ),
#   loss=MSELoss(
#     recent_accumulated_loss=weak_f32[],
#     num_recent=weak_i32[],
#     compute_loss=_ValueAndGradWrapper(
#       _fun=<function compute_mse_loss>,
#       _has_aux=False,
#       _gradkwargs={}
#     )
#   ),
#   optimizer=AdamOptimizer(
#     state=(
#       ScaleByAdamState(
#         count=i32[],
#         mu=CNN(
#           layers=[
#             Conv2d(
#               num_spatial_dims=2,
#               weight=f32[32,1,3,3],
#               bias=f32[32,1,1],
#               in_channels=1,
#               out_channels=32,
#               kernel_size=(3, 3),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               dilation=(1, 1),
#               groups=1,
#               use_bias=True,
#               padding_mode='ZEROS'
#             ),
#             None,
#             MaxPool2d(
#               init=None,
#               operation=None,
#               num_spatial_dims=2,
#               kernel_size=(2, 2),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               use_ceil=False
#             ),
#             Conv2d(
#               num_spatial_dims=2,
#               weight=f32[64,32,3,3],
#               bias=f32[64,1,1],
#               in_channels=32,
#               out_channels=64,
#               kernel_size=(3, 3),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               dilation=(1, 1),
#               groups=1,
#               use_bias=True,
#               padding_mode='ZEROS'
#             ),
#             None,
#             MaxPool2d(
#               init=None,
#               operation=None,
#               num_spatial_dims=2,
#               kernel_size=(2, 2),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               use_ceil=False
#             ),
#             None,
#             Linear(
#               weight=f32[128,30976],
#               bias=f32[128],
#               in_features=30976,
#               out_features=128,
#               use_bias=True
#             ),
#             None,
#             Linear(
#               weight=f32[10,128],
#               bias=f32[10],
#               in_features=128,
#               out_features=10,
#               use_bias=True
#             ),
#             None
#           ]
#         ),
#         nu=CNN(
#           layers=[
#             Conv2d(
#               num_spatial_dims=2,
#               weight=f32[32,1,3,3],
#               bias=f32[32,1,1],
#               in_channels=1,
#               out_channels=32,
#               kernel_size=(3, 3),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               dilation=(1, 1),
#               groups=1,
#               use_bias=True,
#               padding_mode='ZEROS'
#             ),
#             None,
#             MaxPool2d(
#               init=None,
#               operation=None,
#               num_spatial_dims=2,
#               kernel_size=(2, 2),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               use_ceil=False
#             ),
#             Conv2d(
#               num_spatial_dims=2,
#               weight=f32[64,32,3,3],
#               bias=f32[64,1,1],
#               in_channels=32,
#               out_channels=64,
#               kernel_size=(3, 3),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               dilation=(1, 1),
#               groups=1,
#               use_bias=True,
#               padding_mode='ZEROS'
#             ),
#             None,
#             MaxPool2d(
#               init=None,
#               operation=None,
#               num_spatial_dims=2,
#               kernel_size=(2, 2),
#               stride=(1, 1),
#               padding=((0, 0), (0, 0)),
#               use_ceil=False
#             ),
#             None,
#             Linear(
#               weight=f32[128,30976],
#               bias=f32[128],
#               in_features=30976,
#               out_features=128,
#               use_bias=True
#             ),
#             None,
#             Linear(
#               weight=f32[10,128],
#               bias=f32[10],
#               in_features=128,
#               out_features=10,
#               use_bias=True
#             ),
#             None
#           ]
#         )
#       ),
#       EmptyState()
#     ),
#     optim=GradientTransformationExtraArgs(
#       init=<function init_fn>,
#       update=<function update_fn>
#     )
#   ),
#   timestamps=TimeStamps(
#     first_start_time=1731014808.588118,
#     last_restart_time=1731014808.588118
#   )
# )

# %% [markdown]
# ## Training the model
#
# To keep track of training along the way, we need to use the `orbax.checkpoint` module to create a `ChackpointManager` object.
# This object is passed into the training loop function.
#
# Run the following cell, but manually interrupt it after 20 seconds to simulate a crash.

# %%
import orbax.checkpoint as ocp

# Read in the hyperparameters
hyperparams = read_yaml("hyperparams.yml")

# Set up the checkpoint manager
ckpt_dir = hyperparams['train']['checkpoint_directory']
ckpt_options = ocp.CheckpointManagerOptions(max_to_keep=5, enable_async_checkpointing=True)
checkpoint_manager = ocp.CheckpointManager(directory=ckpt_dir, options=ckpt_options)

# Do training
run_training(hyperparams=hyperparams, reset=True, checkpoint_manager=checkpoint_manager)

# Close the checkpoint manager
checkpoint_manager.close()
# Out:
# Epoch 1/3	Batch 20/1875	Loss: 1.79795	Total run time:  0 h  0 m  6.4 s	Time since last restart:  0 h  0 m  6.4 s
# Epoch 1/3	Batch 40/1875	Loss: 0.73513	Total run time:  0 h  0 m 13.1 s	Time since last restart:  0 h  0 m 13.0 s
# Epoch 1/3	Batch 60/1875	Loss: 0.41160	Total run time:  0 h  0 m 19.4 s	Time since last restart:  0 h  0 m 19.3 s
# Epoch 1/3	Batch 80/1875	Loss: 0.31436	Total run time:  0 h  0 m 26.1 s	Time since last restart:  0 h  0 m 26.1 s
# Epoch 1/3	Batch 100/1875	Loss: 0.25971	Total run time:  0 h  0 m 32.7 s	Time since last restart:  0 h  0 m 32.6 s
# Epoch 1/3	Batch 120/1875	Loss: 0.18693	Total run time:  0 h  0 m 38.7 s	Time since last restart:  0 h  0 m 38.6 s
# Epoch 1/3	Batch 140/1875	Loss: 0.16544	Total run time:  0 h  0 m 44.7 s	Time since last restart:  0 h  0 m 44.6 s
# Epoch 1/3	Batch 160/1875	Loss: 0.18894	Total run time:  0 h  0 m 51.1 s	Time since last restart:  0 h  0 m 51.0 s
# Epoch 1/3	Batch 180/1875	Loss: 0.15636	Total run time:  0 h  0 m 57.5 s	Time since last restart:  0 h  0 m 57.4 s
# Epoch 1/3	Batch 200/1875	Loss: 0.19507	Total run time:  0 h  1 m  3.6 s	Time since last restart:  0 h  1 m  3.5 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 12
#       9 checkpoint_manager = ocp.CheckpointManager(directory=ckpt_dir, options=ckpt_options)
#      11 # Do training
# ---> 12 run_training(hyperparams=hyperparams, reset=True, checkpoint_manager=checkpoint_manager)
#      14 # Close the checkpoint manager
#      15 checkpoint_manager.close()
#
# File ~/Documents/mydocs/software/ml-templates/src/ml_templates/state_evolution/train_with_checkpoints/train.py:125, in run_training(hyperparams, reset, checkpoint_manager)
#     123 state_no_dataloader_state_dict = eqx.tree_at(lambda x: x.dataloader.train_state_dict, state, 0)  # Remove dataloader from state by replacing it with a dummy "zero" value
#     124 iterdata = IterData(epoch=None, batch=(i, batch_data))
# --> 125 state_no_dataloader_state_dict = train_step(state_no_dataloader_state_dict, iterdata)
#     126 # state_no_dataloader = train_step(state_no_dataloader)
#     127 state = eqx.tree_at(lambda x: x.dataloader.train_state_dict, state_no_dataloader_state_dict, dataloader_state_dict)
#
#     [... skipping hidden 4 frame]
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:356, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     353 if config.no_tracing.value:
#     354   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     355                      "`jit`, but 'no_tracing' is set")
# --> 356 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     357     fun, jit_info, *args, **kwargs)
#     358 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     359 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:179, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     178 def _python_pjit_helper(fun, jit_info, *args, **kwargs):
# --> 179   p, args_flat = _infer_params(fun, jit_info, args, kwargs)
#     181   for arg in args_flat:
#     182     dispatch.check_arg(arg)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:773, in _infer_params(fun, ji, args, kwargs)
#     770 entry = _infer_params_cached(
#     771     fun, ji, signature, avals, pjit_mesh, resource_env)
#     772 if entry.pjit_params is None:
# --> 773   p, args_flat = _infer_params_impl(
#     774       fun, ji, pjit_mesh, resource_env, args, kwargs, in_avals=avals)
#     775   if p.attrs_tracked:
#     776     # If there are attrs_tracked, don't use the cache.
#     777     return p, p.consts + args_flat
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:670, in _infer_params_impl(***failed resolving arguments***)
#     664 in_shardings_flat, in_layouts_flat = _process_in_axis_resources(
#     665     in_shardings_treedef, in_shardings_leaves,
#     666     ji.in_layouts_treedef, ji.in_layouts_leaves,
#     667     in_avals, in_tree, dbg, device_or_backend_set, have_kwargs)
#     669 attr_token = _attr_token(flat_fun, in_type)
# --> 670 jaxpr, consts, out_avals, attrs_tracked = _create_pjit_jaxpr(
#     671     flat_fun, in_type, attr_token, dbg,
#     672     HashableFunction(res_paths, closure=()),
#     673     IgnoreKey(ji.inline))
#     674 _attr_update(flat_fun, in_type, attr_token, attrs_tracked)
#     676 out_shardings_flat, out_layouts_flat = _check_and_canonicalize_out_shardings(
#     677     out_shardings_treedef, out_shardings_leaves, ji.out_layouts_treedef,
#     678     ji.out_layouts_leaves, HashableFunction(out_tree, closure=()),
#     679     tuple(out_avals), jaxpr.jaxpr.debug_info, device_or_backend_set)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/linear_util.py:352, in cache.<locals>.memoized_fun(fun, *args)
#     350   fun.populate_stores(stores)
#     351 else:
# --> 352   ans = call(fun, *args)
#     353   if explain and config.explain_cache_misses.value:
#     354     explain(fun.f, cache is new_cache, cache, key)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1314, in _create_pjit_jaxpr(***failed resolving arguments***)
#    1312     attrs_tracked = []
#    1313   else:
# -> 1314     jaxpr, global_out_avals, consts, attrs_tracked = pe.trace_to_jaxpr_dynamic(
#    1315         fun, in_type, debug_info=pe_debug)
#    1316     # assert attr_data is sentinel or attr_data matches attrs_tracked
#    1317
#    1318 # TODO(dougalm,mattjj): enable debug info with attrs_tracked
#    1319 if not config.dynamic_shapes.value and not attrs_tracked:
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2278, in trace_to_jaxpr_dynamic(fun, in_avals, debug_info, keep_inputs)
#    2276 with core.new_main(DynamicJaxprTrace, dynamic=True) as main:
#    2277   main.jaxpr_stack = ()  # type: ignore
# -> 2278   jaxpr, out_avals, consts, attrs_tracked = trace_to_subjaxpr_dynamic(
#    2279     fun, main, in_avals, keep_inputs=keep_inputs, debug_info=debug_info)
#    2280   del main, fun
#    2281 return jaxpr, out_avals, consts, attrs_tracked
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/interpreters/partial_eval.py:2301, in trace_to_subjaxpr_dynamic(fun, main, in_avals, keep_inputs, debug_info)
#    2299 in_tracers = _input_type_to_tracers(trace.new_arg, in_avals)
#    2300 in_tracers_ = [t for t, keep in zip(in_tracers, keep_inputs) if keep]
# -> 2301 ans = fun.call_wrapped(*in_tracers_)
#    2302 out_tracers = map(trace.full_raise, ans)
#    2303 jaxpr, consts, attrs_tracked = frame.to_jaxpr(trace, out_tracers)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/linear_util.py:193, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     190 gen = gen_static_args = out_store = None
#     192 try:
# --> 193   ans = self.f(*args, **dict(self.params, **kwargs))
#     194 except:
#     195   # Some transformations yield from inside context managers, so we have to
#     196   # interrupt them before reraising the exception. Otherwise they will only
#     197   # get garbage-collected at some later time, running their cleanup tasks
#     198   # only after this exception is handled, which can corrupt the global
#     199   # state.
#     200   while stack:
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/equinox/_jit.py:51, in _filter_jit_cache.<locals>.fun_wrapped(dynamic_donate, dynamic_nodonate, static)
#      49 *args, dummy_arg = (first_arg,) + rest_args
#      50 assert dummy_arg is None
# ---> 51 out = fun(*args, **kwargs)
#      52 dynamic_out, static_out = partition(out, is_array)
#      53 return dynamic_out, Static(static_out)
#
# File ~/Documents/mydocs/software/ml-templates/src/ml_templates/state_evolution/train_with_checkpoints/update.py:27, in train_step(state, data)
#      24 compute_loss = state.loss.compute_loss
#      26 # Do train step
# ---> 27 loss, grads = compute_loss(model, x, y)
#      28 updates, opt_state = optim.update(grads, opt_state)
#      29 model = eqx.apply_updates(model, updates)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/equinox/_ad.py:80, in _ValueAndGradWrapper.__call__(self, *args, **kwargs)
#      78 x, *args = args
#      79 diff_x, nondiff_x = partition(x, is_inexact_array)
# ---> 80 return fun_value_and_grad(diff_x, nondiff_x, *args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/api.py:468, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     466 _check_scalar(ans)
#     467 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 468 g = vjp_py(lax_internal._one(ans))
#     469 g = g[0] if isinstance(argnums, int) else g
#     470 if not has_aux:
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/lax/lax.py:1737, in full_like(x, fill_value, dtype, shape, sharding)
#    1734 if use_x_sharding:
#    1735   # TODO(yashkatariya): Use shard_alike in tracing_mode once it is supported.
#    1736   sharding = x.sharding  # type: ignore
# -> 1737 val = full(fill_shape, _convert_element_type(fill_value, dtype, weak_type),
#    1738            sharding=sharding)
#    1739 return val
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/lax/lax.py:585, in _convert_element_type(operand, new_dtype, weak_type, sharding)
#     583   return operand
#     584 else:
# --> 585   return convert_element_type_p.bind(
#     586       operand, new_dtype=new_dtype, weak_type=bool(weak_type),
#     587       sharding=sharding)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/lax/lax.py:2865, in _convert_element_type_bind(operand, new_dtype, weak_type, sharding)
#    2864 def _convert_element_type_bind(operand, *, new_dtype, weak_type, sharding):
# -> 2865   operand = core.Primitive.bind(convert_element_type_p, operand,
#    2866                                 new_dtype=new_dtype, weak_type=weak_type,
#    2867                                 sharding=sharding)
#    2868   if sharding is not None:
#    2869     operand = pjit.with_sharding_constraint(operand, sharding)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:438, in Primitive.bind(self, *args, **params)
#     435 def bind(self, *args, **params):
#     436   assert (not config.enable_checks.value or
#     437           all(isinstance(arg, Tracer) or valid_jaxtype(arg) for arg in args)), args
# --> 438   return self.bind_with_trace(find_top_trace(args), args, params)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:1381, in find_top_trace(xs)
#    1380 def find_top_trace(xs) -> Trace:
# -> 1381   top_tracer = max((x for x in xs if isinstance(x, Tracer)),
#    1382                     default=None, key=_get_trace_level)
#    1383   if top_tracer is not None:
#    1384     top_tracer._assert_live()
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:1381, in <genexpr>(.0)
#    1380 def find_top_trace(xs) -> Trace:
# -> 1381   top_tracer = max((x for x in xs if isinstance(x, Tracer)),
#    1382                     default=None, key=_get_trace_level)
#    1383   if top_tracer is not None:
#    1384     top_tracer._assert_live()
#
# KeyboardInterrupt:

# %% [markdown]
# Now, try running the next cell to resume training from where it left off.
# (You can also interrupt this cell after a 20 seconds.)

# %%
run_training(hyperparams=hyperparams, reset=False, checkpoint_manager=checkpoint_manager)
# Out:
# Epoch 1/3	Batch 220/1875	Loss: 0.14781	Total run time:  0 h  1 m 40.9 s	Time since last restart:  0 h  0 m  6.3 s
# Epoch 1/3	Batch 240/1875	Loss: 0.15307	Total run time:  0 h  1 m 47.8 s	Time since last restart:  0 h  0 m 13.2 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 run_training(hyperparams=hyperparams, reset=False, checkpoint_manager=checkpoint_manager)
#
# File ~/Documents/mydocs/software/ml-templates/src/ml_templates/state_evolution/train_with_checkpoints/train.py:125, in run_training(hyperparams, reset, checkpoint_manager)
#     123 state_no_dataloader_state_dict = eqx.tree_at(lambda x: x.dataloader.train_state_dict, state, 0)  # Remove dataloader from state by replacing it with a dummy "zero" value
#     124 iterdata = IterData(epoch=None, batch=(i, batch_data))
# --> 125 state_no_dataloader_state_dict = train_step(state_no_dataloader_state_dict, iterdata)
#     126 # state_no_dataloader = train_step(state_no_dataloader)
#     127 state = eqx.tree_at(lambda x: x.dataloader.train_state_dict, state_no_dataloader_state_dict, dataloader_state_dict)
#
#     [... skipping hidden 4 frame]
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:356, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     353 if config.no_tracing.value:
#     354   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     355                      "`jit`, but 'no_tracing' is set")
# --> 356 outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#     357     fun, jit_info, *args, **kwargs)
#     358 executable = _read_most_recent_pjit_call_executable(jaxpr)
#     359 pgle_profiler = _read_pgle_profiler(jaxpr)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:189, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     186   args_flat = [*init_states, *args_flat]
#     188 try:
# --> 189   out_flat = pjit_p.bind(*args_flat, **p.params)
#     190 except pxla.DeviceAssignmentMismatchError as e:
#     191   fails, = e.args
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:2781, in AxisPrimitive.bind(self, *args, **params)
#    2777 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2778                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2779 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2780              else axis_main.with_cur_sublevel())
# -> 2781 return self.bind_with_trace(top_trace, args, params)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:442, in Primitive.bind_with_trace(self, trace, args, params)
#     440 def bind_with_trace(self, trace, args, params):
#     441   with pop_level(trace.level):
# --> 442     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     443   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/core.py:948, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     946   return call_impl_with_key_reuse_checks(primitive, primitive.impl, *tracers, **params)
#     947 else:
# --> 948   return primitive.impl(*tracers, **params)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1764, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1755 if xla_extension_version >= 286:
#    1756   cache_key = pxla.JitGlobalCppCacheKeys(
#    1757       donate_argnums=donated_argnums, donate_argnames=None,
#    1758       device=None, backend=None,
#    (...)
#    1762       out_layouts_treedef=None, out_layouts_leaves=out_layouts,
#    1763       use_resource_env=resource_env is not None)
# -> 1764   return xc._xla.pjit(
#    1765       name, f, call_impl_cache_miss, [], [], cache_key,
#    1766       tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1767       _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#    1768 else:
#    1769   has_explicit_sharding = _pjit_explicit_sharding_and_layout(
#    1770       in_shardings, out_shardings, in_layouts, out_layouts, None, None)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1739, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1738 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1739   out_flat, compiled = _pjit_call_impl_python(
#    1740       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1741       out_shardings=out_shardings, in_layouts=in_layouts,
#    1742       out_layouts=out_layouts, resource_env=resource_env,
#    1743       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1744       inline=inline)
#    1745   pgle_profiler = _read_pgle_profiler(jaxpr)
#    1746   fastpath_data = _get_fastpath_data(
#    1747       compiled, tree_structure(out_flat), args, out_flat, [], jaxpr.effects,
#    1748       jaxpr.consts, None, pgle_profiler)
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/pjit.py:1669, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1656     compile_options = {'fdo_profile': fdo_profile}
#    1658 # TODO(patrios): Do not pass mutable profile session through cached lowering
#    1659 # chain. Instead we need to move profilers dictionary to pxla module and use
#    1660 # module as key. Right now we can't do that since there is no way to evict _pjit_lower_cached cache for in PGLE mode.
#    1661 compiled = _resolve_and_lower(
#    1662     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1663     out_shardings=out_shardings, in_layouts=in_layouts,
#    1664     out_layouts=out_layouts, resource_env=resource_env,
#    1665     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1666     inline=inline, lowering_platforms=None,
#    1667     lowering_parameters=mlir.LoweringParameters(),
#    1668     pgle_profiler=pgle_profiler
# -> 1669 ).compile(compile_options)
#    1671 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1672 # This check is expensive so only do it if enable_checks is on.
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2315, in MeshComputation.compile(self, compiler_options)
#    2313 def compile(self, compiler_options=None) -> MeshExecutable:
#    2314   if self._executable is None or compiler_options is not None:
# -> 2315     executable = UnloadedMeshExecutable.from_hlo(
#    2316         self._name, self._hlo, **self.compile_args,
#    2317         compiler_options=compiler_options)
#    2318     if compiler_options is None:
#    2319       self._executable = executable
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2829, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2826       mesh = i.mesh  # type: ignore
#    2827       break
# -> 2829 xla_executable = _cached_compilation(
#    2830     hlo, name, mesh, spmd_lowering,
#    2831     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2832     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2833     compiler_options_keys, compiler_options_values, pgle_profiler)
#    2835 if auto_spmd_lowering:
#    2836   assert mesh is not None
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2641, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values, pgle_profiler)
#    2633 compile_options = create_compile_options(
#    2634     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2635     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2636     dev, pmap_nreps, compiler_options)
#    2638 with dispatch.log_elapsed_time(
#    2639     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2640     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2641   xla_executable = compiler.compile_or_get_cached(
#    2642       backend, computation, dev, compile_options, host_callbacks,
#    2643       pgle_profiler)
#    2644 return xla_executable
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/compiler.py:427, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     425 else:
#     426   log_persistent_cache_miss(module_name, cache_key)
# --> 427   return _compile_and_write_cache(
#     428       backend,
#     429       computation,
#     430       compile_options,
#     431       host_callbacks,
#     432       module_name,
#     433       cache_key,
#     434   )
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/compiler.py:655, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     646 def _compile_and_write_cache(
#     647     backend: xc.Client,
#     648     computation: ir.Module,
#    (...)
#     652     cache_key: str,
#     653 ) -> xc.LoadedExecutable:
#     654   start_time = time.monotonic()
# --> 655   executable = backend_compile(
#     656       backend, computation, compile_options, host_callbacks
#     657   )
#     658   compile_time = time.monotonic() - start_time
#     659   _cache_write(
#     660       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     661   )
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/profiler.py:333, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     330 @wraps(func)
#     331 def wrapper(*args, **kwargs):
#     332   with TraceAnnotation(name, **decorator_kwargs):
# --> 333     return func(*args, **kwargs)
#     334   return wrapper
#
# File ~/Documents/mydocs/software/ml-templates/.venv/lib/python3.11/site-packages/jax/_src/compiler.py:267, in backend_compile(backend, module, options, host_callbacks)
#     261     return backend.compile(
#     262         built_c, compile_options=options, host_callbacks=host_callbacks
#     263     )
#     264   # Some backends don't have `host_callbacks` option yet
#     265   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     266   # to take in `host_callbacks`
# --> 267   return backend.compile(built_c, compile_options=options)
#     268 except xc.XlaRuntimeError as e:
#     269   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %% [markdown]
# Training continues from the last checkpoint!

# %% [markdown]
# ## Saving and loading models
#
# We can load the train state and/or the model from any checkpoint:

# %%
from ml_templates.state_evolution.train_with_checkpoints import load_state, load_model

# Loads the state from the latest checkpoint
latest_state = load_state(checkpoint_manager)

# Loads the state from a user-specified checkpoint
user_specified_step = checkpoint_manager.all_steps()[1]
another_state = load_state(checkpoint_manager, step=user_specified_step)

# Loads the model from the latest checkpoint
latest_model = load_model(checkpoint_manager)

# Loads the model from a user-specified checkpoint
another_model = load_model(checkpoint_manager, step=user_specified_step)

# %% [markdown]
# If we are done training, then we can save the latest model as the final model:

# %%
from ml_templates.state_evolution.train_with_checkpoints import save_final_model, load_final_model

# Save the final model
save_final_model(latest_state, hyperparams)

# Load the final model
final_model = load_final_model(hyperparams)

final_model == latest_state.model
# Out:
# Array(True, dtype=bool)
